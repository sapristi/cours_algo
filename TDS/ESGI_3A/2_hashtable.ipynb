# %%
from IPython.display import display, HTML
display(HTML("""<button type="button" id="button_for_indexeddb">Clear notebook 2_hashtable.ipynb</button>    <script>    window.button_for_indexeddb.onclick = function(e) {        window.indexedDB.open('JupyterLite Storage').onsuccess = function(e) {            let tables = ["checkpoints", "files"];            let t = e.target.result.transaction(tables, "readwrite");            function clearNotenook(tablename) {                t.objectStore(tablename).delete('2_hashtable.ipynb').onsuccess = function(e) {                    console.log("Deleted 2_hashtable.ipynb state in " + tablename + " (" + e.target.result + ")");                }            }            for (let tablename of tables) {                clearNotenook(tablename);            }        }    };    </script>"""))

# %% [markdown]
# # BDD

# %%
class Column[T]:
    def __init__(self, name):
        self.name = name
        self.values = List()

class BDD:
    def __init__(self):
        self.columns = List()

# %% [markdown]
# ## BookTable

# %% [markdown]
# Un marchand de livres veut ranger ses livres de manière à pouvoir les retrouver rapidement. Pour ce faire, il décide de fabriquer une grande étagère carrée.
# Chaque livre sera rangé dans l'étagère suivant les deux premières lettres de son titre:
#
# <!-- ![image.png](attachment:8c1e1d8c-2df9-4f2c-88ad-aed505a9392e.png) -->
#
# <div><img src="attachment:8c1e1d8c-2df9-4f2c-88ad-aed505a9392e.png" width="500" /></div>
#
# Implémenter une classe BookTable avec les méthodes suivantes:
#
# ```python
# class BookTable:
#     def __init__(self):
#         self.étagère = defaultdict(list)
#     def ajout_livre(self, livre: str):
#         ...
#     def possède_livre(self, livre: str):
#         ...
#     def enlève_livre(self, livre: str):
#         ...
# ```
# ( pour simplifier, on considèrera les livres comme étant des chaînes de caractères, et que le titre d'un livre a toujours au moins 2 caractères. )

# %%
class BookTable:
    def __init__(self, capacity):
        pass
