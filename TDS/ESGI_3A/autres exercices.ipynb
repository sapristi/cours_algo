# %%
from IPython.display import display, HTML
display(HTML("""<button type="button" id="button_for_indexeddb">Clear notebook ESGI_3A/autres exercices.ipynb</button>    <script>    window.button_for_indexeddb.onclick = function(e) {        window.indexedDB.open('JupyterLite Storage').onsuccess = function(e) {            let tables = ["checkpoints", "files"];            let t = e.target.result.transaction(tables, "readwrite");            function clearNotenook(tablename) {                t.objectStore(tablename).delete('ESGI_3A/autres exercices.ipynb').onsuccess = function(e) {                    console.log("Deleted ESGI_3A/autres exercices.ipynb state in " + tablename + " (" + e.target.result + ")");                }            }            for (let tablename of tables) {                clearNotenook(tablename);            }        }    };    </script>"""))

# %% [markdown]
# # Autres exercices
#
# - afficher les éléments d'une liste
# - afficher les éléments d'une liste en sens inverse
# - afficher les éléments d'un arbre
# - afficher les éléments d'un arbre en sens inverse
